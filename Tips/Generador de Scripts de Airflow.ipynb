# %% [markdown]
# # VARIABLES FOR TESTING

# %%
# Lista ampliada de posibles variables (200 variables)
posibles_variables = [
    # Conexión a base de datos
    "db_host", "db_port", "db_name", "db_user", "db_password",
    # Credenciales de API
    "api_key", "secret_key", "api_url", "api_timeout", "api_retries",
    # Configuración de sistema
    "log_level", "file_path", "max_connections", "timeout", "retry_interval",
    # Información de usuario
    "user_email", "user_id", "user_role", "user_timezone", "user_preferences",
    # Configuración de red
    "proxy_host", "proxy_port", "proxy_user", "proxy_password", "vpn_enabled",
    # Configuración de cache
    "cache_host", "cache_port", "cache_ttl", "cache_max_size", "cache_policy",
    # Configuración de seguridad
    "encryption_key", "encryption_algo", "auth_token", "jwt_secret", "csrf_token",
    # Configuración de mensajes
    "email_host", "email_port", "email_user", "email_password", "email_from",
    # Configuración de archivos
    "input_file_path", "output_file_path", "temp_dir", "archive_dir", "file_format",
    # Configuración de notificaciones
    "slack_webhook_url", "sms_gateway", "push_service_key", "alert_threshold", "notification_email",
    # Configuración de entorno
    "env_name", "env_type", "region", "availability_zone", "data_center",
    # Configuración de monitoreo
    "monitoring_host", "monitoring_port", "monitoring_interval", "monitoring_api_key", "monitoring_dashboard_url",
    # Configuración de backup
    "backup_host", "backup_port", "backup_path", "backup_frequency", "backup_retention",
    # Configuración de machine learning
    "ml_model_path", "ml_model_version", "ml_framework", "ml_data_source", "ml_prediction_threshold",
    # Configuración de base de datos no relacional
    "nosql_db_host", "nosql_db_port", "nosql_db_name", "nosql_db_user", "nosql_db_password",
    # Configuración de servicios externos
    "external_service_url", "external_service_key", "external_service_timeout", "external_service_retries", "external_service_headers",
    # Configuración de balanceador de carga
    "load_balancer_ip", "load_balancer_port", "load_balancer_strategy", "load_balancer_health_check", "load_balancer_timeout",
    # Configuración de microservicios
    "microservice_name", "microservice_version", "microservice_deploy_url", "microservice_replicas", "microservice_health_check_url",
    # Configuración de contenedores
    "container_image", "container_tag", "container_registry", "container_volume", "container_network",
    # Configuración de orquestación
    "orchestrator_host", "orchestrator_port", "orchestrator_api_version", "orchestrator_auth_token", "orchestrator_max_concurrent_tasks",
    # Configuración de CI/CD
    "cicd_pipeline_name", "cicd_trigger", "cicd_stage", "cicd_artifact_path", "cicd_deploy_env",
    # Variables de entorno
    "env_var_1", "env_var_2", "env_var_3", "env_var_4", "env_var_5",
    # Configuración de analítica
    "analytics_tool", "analytics_api_key", "analytics_project_id", "analytics_event_name", "analytics_batch_size",
    # Configuración de pagos
    "payment_gateway_url", "payment_gateway_key", "payment_gateway_secret", "payment_gateway_currency", "payment_gateway_timeout",
    # Configuración de redes sociales
    "social_media_api_key", "social_media_api_secret", "social_media_account", "social_media_post_template", "social_media_schedule_time",
    # Configuración de recursos
    "resource_cpu_limit", "resource_memory_limit", "resource_disk_limit", "resource_gpu_limit", "resource_network_bandwidth",
    # Configuración de cloud
    "cloud_provider", "cloud_region", "cloud_service_account", "cloud_storage_bucket", "cloud_function_url",
    # Configuración de autoscaling
    "autoscaling_min_instances", "autoscaling_max_instances", "autoscaling_cpu_threshold", "autoscaling_memory_threshold", "autoscaling_schedule",
    # Configuración de almacenamiento
    "storage_type", "storage_capacity", "storage_access_mode", "storage_class", "storage_encryption_key",
    # Configuración de redireccionamiento
    "redirect_url", "redirect_status_code", "redirect_domain", "redirect_path", "redirect_timeout",
    # Configuración de certificados
    "cert_path", "cert_key_path", "cert_ca_path", "cert_passphrase", "cert_issuer",
    # Configuración de sincronización
    "sync_source", "sync_target", "sync_schedule", "sync_method", "sync_retry_policy",
    # Configuración de compresión
    "compression_algo", "compression_level", "compression_output_dir", "compression_include_patterns", "compression_exclude_patterns",
    # Configuración de autenticación
    "auth_provider", "auth_client_id", "auth_client_secret", "auth_redirect_uri", "auth_scope",
    # Configuración de permisos
    "permission_read", "permission_write", "permission_execute", "permission_owner", "permission_group",
    # Configuración de roles
    "role_admin", "role_user", "role_guest", "role_manager", "role_analyst",
    # Configuración de tokens
    "token_type", "token_expiry", "token_issuer", "token_audience", "token_signature_algorithm",
    # Configuración de sesiones
    "session_timeout", "session_cookie_name", "session_cookie_secure", "session_persistence", "session_storage_backend",
    # Configuración de limpieza
    "cleanup_temp_files", "cleanup_logs", "cleanup_old_backups", "cleanup_archives", "cleanup_cache",
    # Configuración de bases de datos distribuidas
    "distributed_db_host", "distributed_db_port", "distributed_db_name", "distributed_db_user", "distributed_db_password",
    # Configuración de aplicaciones móviles
    "mobile_app_id", "mobile_app_version", "mobile_app_platform", "mobile_app_push_token", "mobile_app_api_endpoint",
    # Configuración de tiempos de espera
    "timeout_short", "timeout_medium", "timeout_long", "timeout_critical", "timeout_extended",
    # Configuración de servidores
    "server_ip", "server_port", "server_username", "server_password", "server_ssh_key",
    # Configuración de logs
    "log_rotation_policy", "log_max_size", "log_backup_count", "log_compression_format", "log_storage_path",
    # Configuración de identidades
    "identity_provider", "identity_user_pool", "identity_group_pool", "identity_token", "identity_federation",
    # Configuración de menús
    "menu_items", "menu_order", "menu_visibility", "menu_icons", "menu_shortcuts",
    # Configuración de reportes
    "report_template", "report_schedule", "report_format", "report_recipients", "report_source",
    # Configuración de dashboards
    "dashboard_layout", "dashboard_widgets", "dashboard_data_source", "dashboard_refresh_rate", "dashboard_theme",
    # Configuración de pruebas
    "test_suite", "test_case", "test_data", "test_environment", "test_results_dir",
    # Configuración de migraciones
    "migration_source", "migration_target", "migration_strategy", "migration_schedule", "migration_rollback_policy",
    # Configuración de archivado
    "archive_path", "archive_compression", "archive_retention_period", "archive_encryption", "archive_access_mode",
    # Configuración de IoT
    "iot_device_id", "iot_device_type", "iot_data_frequency", "iot_data_format", "iot_gateway_url",
    # Configuración de blockchain
    "blockchain_node_url", "blockchain_network", "blockchain_contract_address", "blockchain_wallet_address", "blockchain_gas_limit",
    # Configuración de bases de datos gráficas
    "graph_db_host", "graph_db_port", "graph_db_name", "graph_db_user", "graph_db_password",
    # Configuración de flujo de trabajo
    "workflow_name", "workflow_version", "workflow_steps", "workflow_timeout", "workflow_error_handling",
    # Configuración de contenido
    "content_type", "content_source", "content_destination", "content_cdn_url", "content_expiration",
    # Configuración de caching
    "caching_strategy", "caching_ttl", "caching_backend", "caching_policies", "caching_invalidation",
    # Configuración de streaming
    "streaming_endpoint", "streaming_protocol", "streaming_buffer_size", "streaming_reconnect_delay", "streaming_auth_token",
    # Configuración de templates
    "template_path", "template_variables", "template_language", "template_version", "template_engine",
    # Configuración de marketing
    "marketing_campaign_id", "marketing_channel", "marketing_audience", "marketing_budget", "marketing_kpi",
    # Configuración de video
    "video_format", "video_resolution", "video_bitrate", "video_codec", "video_subtitles",
    # Configuración de imagen
    "image_format", "image_resolution", "image_compression", "image_metadata", "image_color_space",
    # Configuración de sonido
    "audio_format", "audio_bitrate", "audio_channels", "audio_sample_rate", "audio_volume",
    # Configuración de segmentación
    "segmentation_strategy", "segmentation_data_source", "segmentation_model", "segmentation_criteria", "segmentation_output_format",
    # Configuración de tráfico
    "traffic_source", "traffic_medium", "traffic_campaign", "traffic_term", "traffic_content",
    # Configuración de SEO
    "seo_keywords", "seo_meta_description", "seo_title", "seo_canonical_url", "seo_robot_instructions",
    # Configuración de salud
    "health_api_url", "health_api_key", "health_check_interval", "health_alert_threshold", "health_recovery_actions",
    # Configuración de inteligencia artificial
    "ai_model_path", "ai_model_version", "ai_training_data", "ai_inference_endpoint", "ai_model_accuracy",
    # Configuración de visión computacional
    "cv_model_path", "cv_model_version", "cv_inference_endpoint", "cv_image_input_format", "cv_image_output_format",
    # Configuración de procesamiento del lenguaje natural
    "nlp_model_path", "nlp_model_version", "nlp_training_data", "nlp_inference_endpoint", "nlp_language",
    # Configuración de reconocimiento de voz
    "asr_model_path", "asr_model_version", "asr_training_data", "asr_inference_endpoint", "asr_language",
    # Configuración de generación de texto
    "textgen_model_path", "textgen_model_version", "textgen_training_data", "textgen_inference_endpoint", "textgen_output_format",
    # Configuración de reconocimiento de emociones
    "emotion_model_path", "emotion_model_version", "emotion_training_data", "emotion_inference_endpoint", "emotion_labels",
    # Configuración de automóviles autónomos
    "autonomous_car_model_path", "autonomous_car_model_version", "autonomous_car_training_data", "autonomous_car_inference_endpoint", "autonomous_car_control_signals",
    # Configuración de realidad aumentada
    "ar_app_path", "ar_app_version", "ar_data_source", "ar_device_support", "ar_interaction_models",
    # Configuración de realidad virtual
    "vr_app_path", "vr_app_version", "vr_hardware_support", "vr_interaction_models", "vr_device_support",
    # Configuración de hologramas
    "hologram_app_path", "hologram_app_version", "hologram_projection_device", "hologram_control_signals", "hologram_interaction_models",
    # Configuración de drones
    "drone_model_path", "drone_model_version", "drone_control_signals", "drone_sensors_data", "drone_autonomous_modes",
    # Configuración de exoesqueletos
    "exoskeleton_model_path", "exoskeleton_model_version", "exoskeleton_control_signals", "exoskeleton_sensors_data", "exoskeleton_autonomous_modes",
    # Configuración de robots industriales
    "industrial_robot_model_path", "industrial_robot_model_version", "industrial_robot_control_signals", "industrial_robot_sensors_data", "industrial_robot_autonomous_modes",
    # Configuración de dispositivos médicos
    "medical_device_model_path", "medical_device_model_version", "medical_device_sensors_data", "medical_device_control_signals", "medical_device_autonomous_modes",
    # Configuración de sistemas de recomendación
    "recommender_model_path", "recommender_model_version", "recommender_training_data", "recommender_inference_endpoint", "recommender_output_format",
    # Configuración de asistentes virtuales
    "virtual_assistant_model_path", "virtual_assistant_model_version", "virtual_assistant_inference_endpoint", "virtual_assistant_response_format", "virtual_assistant_voice_settings",
    # Configuración de agricultura inteligente
    "smart_agriculture_model_path", "smart_agriculture_model_version", "smart_agriculture_sensors_data", "smart_agriculture_control_signals", "smart_agriculture_autonomous_modes",
]

# %% [markdown]
# # AIRFLOW SCRIPT GENERATOR

# %%
import random
from datetime import datetime
from textwrap import dedent
import os

def generar_script_airflow(posibles_variables, lineas_offset):
    # Plantilla base del script
    script_base = dedent("""
    from airflow import DAG
    from airflow.operators.python_operator import PythonOperator
    from airflow.models import Variable
    from datetime import datetime

    # Definir DAG
    default_args = {
        'owner': 'airflow',
        'depends_on_past': False,
        'start_date': datetime(2023, 8, 9),
        'retries': 1,
    }

    dag = DAG(
        'conexion_varia_{index}',
        default_args=default_args,
        description='Un DAG que utiliza una variedad de variables de Airflow',
        schedule_interval=None,
    )

    # Función para realizar la tarea
    def realizar_tarea(**kwargs):
        # Capturar variables
    """)

    # Seleccionar un número aleatorio de variables de la lista de posibles variables
    numero_variables = random.randint(1, lineas_offset)
    variables_seleccionadas = random.sample(posibles_variables, numero_variables)

    # Generar script con las variables seleccionadas y valores aleatorios
    script_variables = ""
    for var in variables_seleccionadas:
        valor_random = random.choice(posibles_variables)
        valor_random_default = random.choice(posibles_variables)
        script_variables += f"    {var} = Variable.get('{valor_random}', default_var='{valor_random_default}')\n"

    # Seleccionar un número aleatorio de variables de la lista de posibles variables
    numero_variables = random.randint(1, lineas_offset)
    variables_seleccionadas = random.sample(posibles_variables, numero_variables)
    
    script_variables_finales = ""
    for var in variables_seleccionadas:
        valor_random = random.choice(posibles_variables)
        valor_random_default = random.choice(posibles_variables)
        script_variables_finales += f"    {var} = Variable.get('{valor_random}', default_var='{valor_random_default}')\n"

    
    script_tareas = dedent(f"""
    # Asignar variables a funciones
{script_variables}

    print("Variables cargadas exitosamente.")

    # Asignar nuevas variables a funciones
{script_variables_finales}
    """)

    # Definir la tarea de Python
    script_tareas += dedent("""
        realizar_tarea_task = PythonOperator(
            task_id='realizar_tarea',
            provide_context=True,
            python_callable=realizar_tarea,
            dag=dag,
        )

        realizar_tarea_task
    """)

    # Generar el script completo
    script_completo = script_base + script_tareas.format(index=lineas_offset)
    return script_completo

# %% [markdown]
# # PYTHON FILES GENERATORS

# %%
def guardar_scripts(cantidad, posibles_variables, numero_variables, carpeta_salida):
    # Crear la carpeta de salida si no existe
    if not os.path.exists(carpeta_salida):
        os.makedirs(carpeta_salida)
    
    for i in range(cantidad):
        script = generar_script_airflow(posibles_variables, numero_variables)
        nombre_archivo = f"{carpeta_salida}/script_{i + 1}.py"
        
        with open(nombre_archivo, 'w') as archivo:
            archivo.write(script)
        print(f"Script guardado en: {nombre_archivo}")
        
cantidad_scripts = 13  # Número de scripts a generar
numero_variables = 7  # Número de variables por script
carpeta_salida = "/notebooks/scripts_airflow"

guardar_scripts(cantidad_scripts, posibles_variables, numero_variables, carpeta_salida)
# Out:
# Script guardado en: /notebooks/scripts_airflow/script_1.py
# Script guardado en: /notebooks/scripts_airflow/script_2.py
# Script guardado en: /notebooks/scripts_airflow/script_3.py
# Script guardado en: /notebooks/scripts_airflow/script_4.py
# Script guardado en: /notebooks/scripts_airflow/script_5.py
# Script guardado en: /notebooks/scripts_airflow/script_6.py
# Script guardado en: /notebooks/scripts_airflow/script_7.py
# Script guardado en: /notebooks/scripts_airflow/script_8.py
# Script guardado en: /notebooks/scripts_airflow/script_9.py
# Script guardado en: /notebooks/scripts_airflow/script_10.py
# Script guardado en: /notebooks/scripts_airflow/script_11.py
# Script guardado en: /notebooks/scripts_airflow/script_12.py
# Script guardado en: /notebooks/scripts_airflow/script_13.py

# %% [markdown]
# # READ AIRFLOW VARIABLES FROM PYTHON SCRIPTS

# %%
import os
import random
import re
import pandas as pd
# Configurar pandas para mostrar el contenido completo de las celdas
pd.set_option('display.max_colwidth', None)

def buscar_variable_get(directorio, posibles_variables):
    datos = []

    # Expresión regular para capturar la asignación de la variable y los valores en Variable.get()
    patron_variable = re.compile(
        r"(\w+)\s*=\s*Variable\.get\(\s*['\"](.+?)['\"](?:,\s*default_var=(['\"]?.+?['\"]?)|,\s*([\d\w]+))?\s*\)"
    )

    # Recorrer todos los archivos en el directorio
    for nombre_archivo in os.listdir(directorio):
        if nombre_archivo.endswith('.py'):
            ruta_archivo = os.path.join(directorio, nombre_archivo)

            with open(ruta_archivo, 'r') as archivo:
                lineas = archivo.readlines()

                # Buscar las líneas que contienen 'Variable.get'
                for numero_linea, linea in enumerate(lineas, start=1):
                    # Encuentra todas las coincidencias en una línea
                    matches = patron_variable.findall(linea)

                    if matches:
                        for match in matches:
                            variable_name = match[0]  # Nombre de la variable en el script
                            variable_value = match[1]  # Valor usado en Variable.get()
                            default_variable_value = match[2] if match[2] else match[3]  # Valor por defecto o vacío
                            valor_reemplazo = random.choice(posibles_variables)

                            datos.append({
                                'script': nombre_archivo,
                                'line': numero_linea,
                                'content': f"{variable_name} = Variable.get('{variable_value}', default_var={default_variable_value})",
                                'variable_name': variable_name,
                                'variable_value': variable_value,
                                'default_variable_value': default_variable_value if default_variable_value and default_variable_value != "''" else '',
                                'replace': valor_reemplazo
                            })

    # Crear un DataFrame de pandas
    df = pd.DataFrame(datos)
    df.index += 1  # Ajustar el índice para que comience en 1
    return df


# Ejemplo de uso
directorio = '/notebooks/scripts_airflow/'
df_resultado = buscar_variable_get(directorio, posibles_variables)
df_resultado
# Out:
#          script  line  \
# 1   script_1.py    27
# 2   script_1.py    27
# 3   script_1.py    27
# 4   script_1.py    43
# 5   script_1.py    44
# 6   script_1.py    45
# 7   script_1.py    53
# 8   script_1.py    54
# 9   script_1.py    55
# 10  script_1.py    56
#
#                                                                                                content  \
# 1            blockchain_network = Variable.get('vr_interaction_models', default_var='iot_device_type')
# 2                     recommender_inference_endpoint = Variable.get('hologram_app_path', default_var=)
# 3                                         api_key = Variable.get('analytics_batch_size', default_var=)
# 4                         notification_email = Variable.get('archive_dir', default_var='traffic_term')
# 5   recommender_inference_endpoint = Variable.get('hologram_app_path', default_var='marketing_budget')
# ...

# %% [markdown]
# # GENERATE NEW PYTHON SCRIPTS FIXED

# %%
import os
import pandas as pd

def reemplazar_y_guardar_scripts(df, directorio_original, directorio_salida):
    if not os.path.exists(directorio_salida):
        os.makedirs(directorio_salida)

    # Agrupar por nombre del script
    for nombre_script, grupo in df.groupby('script'):
        ruta_original = os.path.join(directorio_original, nombre_script)
        ruta_salida = os.path.join(directorio_salida, nombre_script)
        
        # Leer el contenido original del script
        with open(ruta_original, 'r') as archivo:
            lineas = archivo.readlines()

        # Modificar las líneas según el DataFrame
        lineas_modificadas = lineas[:]
        for _, fila in grupo.iterrows():
            numero_linea = fila['line'] - 1  # Ajustar al índice basado en 0
            valor_reemplazo = fila['replace']
            
            # Reemplazar el valor después del igual
            if ' = ' in lineas_modificadas[numero_linea]:
                partes = lineas_modificadas[numero_linea].split('=')
                # Limpiar espacios y comillas para el nuevo valor
                nuevo_valor = f'"{valor_reemplazo.strip()}"'
                lineas_modificadas[numero_linea] = f"{partes[0].strip()} = {nuevo_valor}\n"

        # Guardar el script modificado
        with open(ruta_salida, 'w') as archivo:
            archivo.writelines(lineas_modificadas)
        print(f"Script modificado guardado en: {ruta_salida}")

# Ejemplo de uso
directorio_original = '/notebooks/scripts_airflow'  # Directorio con los scripts originales
directorio_salida = '/notebooks/scripts_airflow_fixed'  # Directorio para los scripts modificados

reemplazar_y_guardar_scripts(df_resultado, directorio_original, directorio_salida)
# Out:
# Script modificado guardado en: /notebooks/scripts_airflow_fixed/script_1.py
# Script modificado guardado en: /notebooks/scripts_airflow_fixed/script_10.py
# Script modificado guardado en: /notebooks/scripts_airflow_fixed/script_11.py
# Script modificado guardado en: /notebooks/scripts_airflow_fixed/script_12.py
# Script modificado guardado en: /notebooks/scripts_airflow_fixed/script_13.py
# Script modificado guardado en: /notebooks/scripts_airflow_fixed/script_2.py
# Script modificado guardado en: /notebooks/scripts_airflow_fixed/script_3.py
# Script modificado guardado en: /notebooks/scripts_airflow_fixed/script_4.py
# Script modificado guardado en: /notebooks/scripts_airflow_fixed/script_5.py
# Script modificado guardado en: /notebooks/scripts_airflow_fixed/script_6.py
# Script modificado guardado en: /notebooks/scripts_airflow_fixed/script_7.py
# Script modificado guardado en: /notebooks/scripts_airflow_fixed/script_8.py
# ...

# %% [markdown]
# # GENERATE NEW PYTHON SCRIPTS FIXED WITH VARIABLES ON SAME LINE

# %%
import os

def reemplazar_y_guardar_scripts_multivariables(df, directorio_original, directorio_salida):
    if not os.path.exists(directorio_salida):
        os.makedirs(directorio_salida)

    # Agrupar por nombre del script
    for nombre_script, grupo in df.groupby('script'):
        ruta_original = os.path.join(directorio_original, nombre_script)
        ruta_salida = os.path.join(directorio_salida, nombre_script)
        
        # Leer el contenido original del script
        with open(ruta_original, 'r') as archivo:
            lineas = archivo.readlines()

        # Crear un diccionario para actualizar líneas basadas en el DataFrame
        lineas_modificadas = []
        lineas_reemplazadas = {}

        for _, fila in grupo.iterrows():
            numero_linea = fila['line'] - 1  # Ajustar al índice basado en 0
            variable_name = fila['variable_name']
            valor_reemplazo = fila['replace']
            
            # Crear una línea modificada con el nuevo valor
            nueva_linea = f"{variable_name} = \"{valor_reemplazo.strip()}\"\n"
            
            if numero_linea not in lineas_reemplazadas:
                lineas_reemplazadas[numero_linea] = []
            lineas_reemplazadas[numero_linea].append(nueva_linea)

        # Reconstruir el script con las líneas originales y las líneas reemplazadas
        for i, linea in enumerate(lineas):
            if i in lineas_reemplazadas:
                # Añadir las líneas modificadas para las líneas que tienen reemplazos
                for reemplazo in lineas_reemplazadas[i]:
                    lineas_modificadas.append(reemplazo)
            elif 'Variable.get' not in linea:
                # Conservar la línea original si no se actualiza y no contiene Variable.get
                lineas_modificadas.append(linea)

        # Guardar el script modificado
        with open(ruta_salida, 'w') as archivo:
            archivo.writelines(lineas_modificadas)
        print(f"Script modificado guardado en: {ruta_salida}")


# Ejemplo de uso
directorio_original = '/notebooks/scripts_airflow'  # Directorio con los scripts originales
directorio_salida = '/notebooks/scripts_airflow_fixed_multivariables'  # Directorio para los scripts modificados

reemplazar_y_guardar_scripts_multivariables(df_resultado, directorio_original, directorio_salida)
# Out:
# Script modificado guardado en: /notebooks/scripts_airflow_fixed_multivariables/script_1.py

# %% [markdown]
# # READ SCRIPTS CONTENT FOR COMPARE

# %%
def mostrar_contenido_archivo(ruta_archivo):
    """
    Muestra el contenido del archivo especificado en la ruta dada.

    :param ruta_archivo: Ruta completa del archivo que se desea leer.
    :type ruta_archivo: str
    """
    try:
        with open(ruta_archivo, 'r') as archivo:
            contenido = archivo.read()
        print(contenido)
    except FileNotFoundError:
        print(f"El archivo en la ruta {ruta_archivo} no fue encontrado.")
    except IOError as e:
        print(f"Error al leer el archivo: {e}")

# %%
# Ejemplo de uso
ruta = '/notebooks/scripts_airflow/script_1.py'
mostrar_contenido_archivo(ruta)
# Out:
# from airflow import DAG
# from airflow.operators.python_operator import PythonOperator
# from airflow.models import Variable
# from datetime import datetime
#
# # Definir DAG
# default_args = {
#     'owner': 'airflow',
#     'depends_on_past': False,
#     'start_date': datetime(2023, 8, 9),
#     'retries': 1,
# }
#
# dag = DAG(
#     'conexion_varia_{index}',
#     default_args=default_args,
#     description='Un DAG que utiliza una variedad de variables de Airflow',
#     schedule_interval=None,
# )
#
# # Función para realizar la tarea
# def realizar_tarea(**kwargs):
#     # Capturar variables
#
# # Asignar variables a funciones
# blockchain_network = Variable.get('vr_interaction_models', default_var='iot_device_type') recommender_inference_endpoint = Variable.get('hologram_app_path') api_key = Variable.get('analytics_batch_size')
#
# print("Variables cargadas exitosamente.")
#
# # Asignar nuevas variables a funciones
# print("Variables cargadas exitosamente.")
#
# ...

# %%
# Ejemplo de uso
ruta = '/notebooks/scripts_airflow_fixed_multivariables/script_1.py'
mostrar_contenido_archivo(ruta)
# Out:
# from airflow import DAG
# from airflow.operators.python_operator import PythonOperator
# from airflow.models import Variable
# from datetime import datetime
#
# # Definir DAG
# default_args = {
#     'owner': 'airflow',
#     'depends_on_past': False,
#     'start_date': datetime(2023, 8, 9),
#     'retries': 1,
# }
#
# dag = DAG(
#     'conexion_varia_{index}',
#     default_args=default_args,
#     description='Un DAG que utiliza una variedad de variables de Airflow',
#     schedule_interval=None,
# )
#
# # Función para realizar la tarea
# def realizar_tarea(**kwargs):
#     # Capturar variables
#
# # Asignar variables a funciones
# blockchain_network = "cicd_stage"
# recommender_inference_endpoint = "token_expiry"
# api_key = "server_password"
#
# print("Variables cargadas exitosamente.")
#
# # Asignar nuevas variables a funciones
# print("Variables cargadas exitosamente.")
#
# # Asignar nuevas variables a funciones
# print("Variables cargadas exitosamente.")
#
# ...

# %% [markdown]
# # COMPARE SCRIPT DIFFERENCES

# %%
import difflib

def comparar_scripts(ruta_script1, ruta_script2):
    """
    Compara dos scripts y muestra solo las líneas que han cambiado, con números de línea exactos.

    :param ruta_script1: Ruta del primer script.
    :param ruta_script2: Ruta del segundo script.
    """
    try:
        # Leer los contenidos de los scripts
        with open(ruta_script1, 'r') as archivo1, open(ruta_script2, 'r') as archivo2:
            contenido1 = archivo1.readlines()
            contenido2 = archivo2.readlines()

        # Comparar los contenidos
        diferencias = list(difflib.unified_diff(contenido1, contenido2, fromfile=ruta_script1, tofile=ruta_script2))

        # Variables para los números de línea
        numero_linea1 = 1
        numero_linea2 = 1

        # Mostrar las diferencias con números de línea exactos
        for linea in diferencias:
            if linea.startswith('--- '):
                print(f"\n--- {ruta_script1} (Original)\n")
            elif linea.startswith('+++ '):
                print(f"\n+++ {ruta_script2} (Modificado)\n")
            elif linea.startswith('@@ '):
                # Extraer los números de línea de los contextos de diferencia
                partes = linea.split()
                if len(partes) >= 2:
                    numero_linea1 = int(partes[1].split(',')[0].lstrip('+'))
                    numero_linea2 = int(partes[2].split(',')[0].lstrip('+'))
            elif linea.startswith('-'):
                # Mostrar líneas eliminadas del primer script con número de línea
                print(f"{numero_linea1}: {linea[1:].strip()}")
                numero_linea1 += 1
            elif linea.startswith('+'):
                # Mostrar líneas añadidas del segundo script con número de línea
                print(f"    + {numero_linea2}: {linea[1:].strip()}")
                numero_linea2 += 1

    except FileNotFoundError as e:
        print(f"Archivo no encontrado: {e.filename}")
    except IOError as e:
        print(f"Error de entrada/salida: {e}")


# Ejemplo de uso
ruta1 = '/notebooks/scripts_airflow/script_1.py'
ruta2 = '/notebooks/scripts_airflow_fixed_multivariables/script_1.py'

comparar_scripts(ruta1, ruta2)
# Out:
# --- /notebooks/scripts_airflow/script_1.py (Original)
#
#
# +++ /notebooks/scripts_airflow_fixed_multivariables/script_1.py (Modificado)
#
# -24: blockchain_network = Variable.get('vr_interaction_models', default_var='iot_device_type') recommender_inference_endpoint = Variable.get('hologram_app_path') api_key = Variable.get('analytics_batch_size')
#     + 24: blockchain_network = "cicd_stage"
#     + 25: recommender_inference_endpoint = "token_expiry"
#     + 26: api_key = "server_password"
# -35: notification_email = Variable.get('archive_dir', default_var='traffic_term')
# -34: recommender_inference_endpoint = Variable.get('hologram_app_path', default_var='marketing_budget')
# -33: compression_output_dir = Variable.get('redirect_domain', default_var='server_ssh_key')
#     + 37: notification_email = "load_balancer_timeout"
#     + 38: recommender_inference_endpoint = "compression_include_patterns"
#     + 39: compression_output_dir = "streaming_endpoint"
# ...
